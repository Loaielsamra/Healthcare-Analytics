# %%
import pandas as pd

# %%
df = pd.read_csv("../data/clean/appointments_clean.csv")

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show  doctor_id
# 0         0           0        0             0      No          9
# ...

# %%
df.shape
# Out:
# (110527, 15)

# %%
df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# doctor_id         0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 110522    False
# 110523    False
# 110524    False
# 110525    False
# 110526    False
# Length: 110527, dtype: bool

# %%
df_doc = pd.read_csv("../data/clean/doctors.csv")

# %%
df_doc.shape
# Out:
# (50, 4)

# %%
df_doc
# Out:
#     doctor_id                name specialization          hospital
# 0           1     Deanna Mckinney     Pediatrics           Detroit
# 1           2    Priscilla Carter     Cardiology         Waterbury
# 2           3   Miguel Richardson        General           Hayward
# 3           4         Juanita Kim        General          Amarillo
# 4           5       Minnie Nelson        General       San Antonio
# 5           6        Krin Griffin    Dermatology        Greensboro
# 6           7        Curtis Price      Neurology         Frederick
# 7           8       Anthony Myers      Neurology    St. Petersburg
# 8           9       Martha Murphy        General        Clearwater
# 9          10        Grace Brewer    Dermatology            Toledo
# 10         11        Lewis Howell    Dermatology     Miami Gardens
# 11         12          Joy Howell        General  Colorado Springs
# 12         13        Wyatt Barnes      Neurology      North Valley
# ...
